# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing Chipotle Data
#
# _Author: Joseph Nelson (DC)_
#
# ---

# %% [markdown]
# For Project 2, you will complete a series of exercises exploring [order data from Chipotle](https://github.com/TheUpshot/chipotle), compliments of _The New York Times'_ "The Upshot."
#
# For these exercises, you will conduct basic exploratory data analysis (Pandas not required) to understand the essentials of Chipotle's order data: how many orders are being made, the average price per order, how many different ingredients are used, etc. These allow you to practice business analysis skills while also becoming comfortable with Python.

# %% [markdown]
# ---
#
# ## Basic Level

# %% [markdown]
# ### Part 1: Read in the file with `csv.reader()` and store it in an object called `file_nested_list`.
#
# Hint: This is a TSV (tab-separated value) file, and `csv.reader()` needs to be told [how to handle it](https://docs.python.org/2/library/csv.html).

# %%
import csv
from collections import namedtuple   # Convenient to store the data rows

DATA_FILE = './data/chipotle.tsv'

## above code was given

# %%
with open(DATA_FILE,'r') as f:
    #the dialect='excel-tab' specifies that the importing data set is a TSV file type
    reader = csv.DictReader(f, dialect='excel-tab')
    #empty list to constcut the data set
    file_nested_list = []
    for row in reader:
        file_nested_list.append(dict(row))
   
    
file_nested_list
#reader
# Out:
# [{'order_id': '1',
#   'quantity': '1',
#   'item_name': 'Chips and Fresh Tomato Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '1',
#   'quantity': '1',
#   'item_name': 'Izze',
#   'choice_description': '[Clementine]',
#   'item_price': '$3.39 '},
#  {'order_id': '1',
#   'quantity': '1',
#   'item_name': 'Nantucket Nectar',
#   'choice_description': '[Apple]',
#   'item_price': '$3.39 '},
#  {'order_id': '1',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo-Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '2',
#   'quantity': '2',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]',
#   'item_price': '$16.98 '},
#  {'order_id': '3',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$10.98 '},
#  {'order_id': '3',
#   'quantity': '1',
#   'item_name': 'Side of Chips',
#   'choice_description': 'NULL',
#   'item_price': '$1.69 '},
#  {'order_id': '4',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '4',
#   'quantity': '1',
#   'item_name': 'Steak Soft Tacos',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '5',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '5',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '6',
#   'quantity': '1',
#   'item_name': 'Chicken Crispy Tacos',
#   'choice_description': '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '6',
#   'quantity': '1',
#   'item_name': 'Chicken Soft Tacos',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '7',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '7',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '8',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo-Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '8',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Cheese, Sour Cream]]',
#   'item_price': '$8.49 '},
#  {'order_id': '9',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Fresh Tomato Salsa (Mild), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '9',
#   'quantity': '2',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Sprite]',
#   'item_price': '$2.18 '},
#  {'order_id': '10',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '10',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '11',
#   'quantity': '1',
#   'item_name': 'Barbacoa Burrito',
#   'choice_description': '[[Fresh Tomato Salsa (Mild), Tomatillo-Green Chili Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '11',
#   'quantity': '1',
#   'item_name': 'Nantucket Nectar',
#   'choice_description': '[Pomegranate Cherry]',
#   'item_price': '$3.39 '},
#  {'order_id': '12',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[[Tomatillo-Green Chili Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Pinto Beans, Rice, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$10.98 '},
#  {'order_id': '12',
#   'quantity': '1',
#   'item_name': 'Izze',
#   'choice_description': '[Grapefruit]',
#   'item_price': '$3.39 '},
#  {'order_id': '13',
#   'quantity': '1',
#   'item_name': 'Chips and Fresh Tomato Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '13',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Pinto Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '14',
#   'quantity': '1',
#   'item_name': 'Carnitas Burrito',
#   'choice_description': '[[Tomatillo-Green Chili Salsa (Medium), Roasted Chili Corn Salsa (Medium)], [Black Beans, Rice, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '14',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Dr. Pepper]',
#   'item_price': '$1.09 '},
#  {'order_id': '15',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Rice, Cheese, Sour Cream]]',
#   'item_price': '$8.49 '},
#  {'order_id': '15',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo-Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '16',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[[Roasted Chili Corn Salsa (Medium), Fresh Tomato Salsa (Mild)], [Rice, Black Beans, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '16',
#   'quantity': '1',
#   'item_name': 'Side of Chips',
#   'choice_description': 'NULL',
#   'item_price': '$1.69 '},
#  {'order_id': '17',
#   'quantity': '1',
#   'item_name': 'Carnitas Bowl',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '17',
#   'quantity': '1',
#   'item_name': 'Bottled Water',
#   'choice_description': 'NULL',
#   'item_price': '$1.09 '},
#  {'order_id': '18',
#   'quantity': '1',
#   'item_name': 'Chicken Soft Tacos',
#   'choice_description': '[Roasted Chili Corn Salsa, Rice]',
#   'item_price': '$8.75 '},
#  {'order_id': '18',
#   'quantity': '1',
#   'item_name': 'Chicken Soft Tacos',
#   'choice_description': '[Roasted Chili Corn Salsa, [Cheese, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '18',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '18',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.95 '},
#  {'order_id': '19',
#   'quantity': '1',
#   'item_name': 'Barbacoa Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '19',
#   'quantity': '1',
#   'item_name': 'Chips',
#   'choice_description': 'NULL',
#   'item_price': '$2.15 '},
#  {'order_id': '20',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '20',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '20',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '20',
#   'quantity': '1',
#   'item_name': 'Chicken Salad Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '21',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Fajita Veggies, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$10.98 '},
#  {'order_id': '21',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Rice, Fajita Veggies, Cheese]]',
#   'item_price': '$8.99 '},
#  {'order_id': '21',
#   'quantity': '1',
#   'item_name': 'Izze',
#   'choice_description': '[Blackberry]',
#   'item_price': '$3.39 '},
#  {'order_id': '22',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[[Fresh Tomato Salsa (Mild), Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '22',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$3.99 '},
#  {'order_id': '23',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '23',
#   'quantity': '2',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Mountain Dew]',
#   'item_price': '$2.18 '},
#  {'order_id': '24',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$10.98 '},
#  {'order_id': '24',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Sprite]',
#   'item_price': '$1.09 '},
#  {'order_id': '25',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Fresh Tomato Salsa (Mild), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '25',
#   'quantity': '1',
#   'item_name': 'Chips and Fresh Tomato Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '26',
#   'quantity': '1',
#   'item_name': 'Barbacoa Soft Tacos',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Black Beans, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '26',
#   'quantity': '1',
#   'item_name': 'Veggie Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '27',
#   'quantity': '1',
#   'item_name': 'Barbacoa Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '27',
#   'quantity': '1',
#   'item_name': 'Chips',
#   'choice_description': 'NULL',
#   'item_price': '$2.15 '},
#  {'order_id': '28',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '28',
#   'quantity': '1',
#   'item_name': 'Steak Soft Tacos',
#   'choice_description': '[Fresh Tomato Salsa, Cheese]',
#   'item_price': '$9.25 '},
#  {'order_id': '28',
#   'quantity': '1',
#   'item_name': 'Veggie Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '28',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]',
#   'item_price': '$8.75 '},
#  {'order_id': '29',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '29',
#   'quantity': '1',
#   'item_name': 'Steak Soft Tacos',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '30',
#   'quantity': '1',
#   'item_name': 'Izze',
#   'choice_description': '[Blackberry]',
#   'item_price': '$3.39 '},
#  {'order_id': '30',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese]]',
#   'item_price': '$8.99 '},
#  {'order_id': '30',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Fajita Veggies, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$10.98 '},
#  {'order_id': '31',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Rice, Black Beans, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '31',
#   'quantity': '1',
#   'item_name': 'Side of Chips',
#   'choice_description': 'NULL',
#   'item_price': '$1.69 '},
#  {'order_id': '32',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '32',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$3.99 '},
#  {'order_id': '33',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '33',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '34',
#   'quantity': '1',
#   'item_name': 'Chicken Soft Tacos',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '34',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '34',
#   'quantity': '1',
#   'item_name': 'Chips',
#   'choice_description': 'NULL',
#   'item_price': '$2.15 '},
#  {'order_id': '34',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '35',
#   'quantity': '1',
#   'item_name': 'Chicken Soft Tacos',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Cheese, Lettuce, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '35',
#   'quantity': '1',
#   'item_name': 'Chips',
#   'choice_description': 'NULL',
#   'item_price': '$2.15 '},
#  {'order_id': '36',
#   'quantity': '1',
#   'item_name': 'Barbacoa Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Pinto Beans, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '36',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '37',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Rice, Black Beans, Sour Cream, Cheese]]',
#   'item_price': '$8.75 '},
#  {'order_id': '37',
#   'quantity': '1',
#   'item_name': 'Steak Soft Tacos',
#   'choice_description': '[Tomatillo Red Chili Salsa]',
#   'item_price': '$9.25 '},
#  {'order_id': '38',
#   'quantity': '1',
#   'item_name': 'Veggie Bowl',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Pinto Beans, Black Beans, Rice, Fajita Veggies, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '38',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Pinto Beans, Rice, Fajita Veggies, Cheese, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '38',
#   'quantity': '1',
#   'item_name': 'Bottled Water',
#   'choice_description': 'NULL',
#   'item_price': '$1.09 '},
#  {'order_id': '39',
#   'quantity': '1',
#   'item_name': 'Carnitas Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Pinto Beans, Sour Cream, Cheese]]',
#   'item_price': '$9.25 '},
#  {'order_id': '39',
#   'quantity': '1',
#   'item_name': 'Chips and Fresh Tomato Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.95 '},
#  {'order_id': '40',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole]]',
#   'item_price': '$11.75 '},
#  {'order_id': '40',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Cheese, Sour Cream, Guacamole]]',
#   'item_price': '$11.75 '},
#  {'order_id': '40',
#   'quantity': '1',
#   'item_name': 'Steak Crispy Tacos',
#   'choice_description': '[Fresh Tomato Salsa, Sour Cream]',
#   'item_price': '$9.25 '},
#  {'order_id': '41',
#   'quantity': '1',
#   'item_name': 'Carnitas Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa, [Sour Cream, Guacamole]]',
#   'item_price': '$11.75 '},
#  {'order_id': '41',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '42',
#   'quantity': '1',
#   'item_name': 'Barbacoa Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream]]',
#   'item_price': '$9.25 '},
#  {'order_id': '42',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '43',
#   'quantity': '1',
#   'item_name': 'Carnitas Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '43',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese]]',
#   'item_price': '$8.75 '},
#  {'order_id': '44',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Fajita Vegetables, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '44',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '45',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo-Green Chili Salsa (Medium), [Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '45',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Tomatillo-Green Chili Salsa (Medium), [Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '45',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$3.99 '},
#  {'order_id': '46',
#   'quantity': '1',
#   'item_name': 'Veggie Burrito',
#   'choice_description': '[Fresh Tomato Salsa (Mild), [Black Beans, Rice, Fajita Veggies, Sour Cream, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '46',
#   'quantity': '1',
#   'item_name': 'Nantucket Nectar',
#   'choice_description': '[Pineapple Orange Banana]',
#   'item_price': '$3.39 '},
#  {'order_id': '47',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Rice, Black Beans, Fajita Veggies, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '47',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Dr. Pepper]',
#   'item_price': '$1.09 '},
#  {'order_id': '48',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '48',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '49',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '49',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo Red Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.95 '},
#  {'order_id': '49',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '50',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo-Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '50',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Rice, Cheese, Sour Cream]]',
#   'item_price': '$8.49 '},
#  {'order_id': '51',
#   'quantity': '1',
#   'item_name': 'Barbacoa Bowl',
#   'choice_description': '[[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Green Chili Salsa (Medium)], [Rice, Pinto Beans, Fajita Veggies, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '51',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Green Chili Salsa (Medium)], [Rice, Pinto Beans, Cheese, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '51',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Diet Dr. Pepper]',
#   'item_price': '$1.09 '},
#  {'order_id': '52',
#   'quantity': '1',
#   'item_name': 'Steak Soft Tacos',
#   'choice_description': '[[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '52',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$3.99 '},
#  {'order_id': '53',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '53',
#   'quantity': '1',
#   'item_name': 'Barbacoa Burrito',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '53',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '54',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Guacamole, Cheese, Sour Cream, Fajita Vegetables, Rice]]',
#   'item_price': '$11.25 '},
#  {'order_id': '54',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '55',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Rice, Black Beans, Fajita Veggies, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '55',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Coca Cola]',
#   'item_price': '$1.09 '},
#  {'order_id': '56',
#   'quantity': '1',
#   'item_name': 'Barbacoa Bowl',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Pinto Beans, Cheese, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '56',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo Red Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.95 '},
#  {'order_id': '56',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '57',
#   'quantity': '1',
#   'item_name': 'Barbacoa Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Pinto Beans, Cheese, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '57',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '58',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Rice, Cheese, Sour Cream]]',
#   'item_price': '$8.49 '},
#  {'order_id': '58',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo-Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '59',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Rice, Black Beans, Sour Cream, Guacamole]]',
#   'item_price': '$10.98 '},
#  {'order_id': '60',
#   'quantity': '2',
#   'item_name': 'Chicken Salad Bowl',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Sour Cream, Cheese, Guacamole]]',
#   'item_price': '$22.50 '},
#  {'order_id': '61',
#   'quantity': '1',
#   'item_name': 'Barbacoa Bowl',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '61',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '62',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Fajita Vegetables, Sour Cream, Cheese, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '62',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '63',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Rice, Sour Cream, Cheese, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '63',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '64',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '64',
#   'quantity': '1',
#   'item_name': 'Veggie Bowl',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Cheese, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '65',
#   'quantity': '1',
#   'item_name': 'Barbacoa Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Sour Cream, Cheese, Guacamole]]',
#   'item_price': '$11.75 '},
#  {'order_id': '65',
#   'quantity': '1',
#   'item_name': 'Carnitas Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese]]',
#   'item_price': '$9.25 '},
#  {'order_id': '65',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '66',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo-Green Chili Salsa (Medium), [Rice, Black Beans, Sour Cream, Guacamole]]',
#   'item_price': '$11.48 '},
#  {'order_id': '67',
#   'quantity': '2',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$17.98 '},
#  {'order_id': '67',
#   'quantity': '1',
#   'item_name': 'Side of Chips',
#   'choice_description': 'NULL',
#   'item_price': '$1.69 '},
#  {'order_id': '68',
#   'quantity': '2',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce]]',
#   'item_price': '$17.50 '},
#  {'order_id': '68',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '69',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Rice, Cheese, Sour Cream]]',
#   'item_price': '$8.49 '},
#  {'order_id': '69',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo-Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '70',
#   'quantity': '2',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Lettuce]]',
#   'item_price': '$17.50 '},
#  {'order_id': '70',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '71',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '71',
#   'quantity': '1',
#   'item_name': 'Veggie Bowl',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '71',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Rice, Cheese, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '72',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$10.98 '},
#  {'order_id': '73',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa (Mild), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '73',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Fajita Veggies, Cheese, Guacamole, Lettuce]]',
#   'item_price': '$10.98 '},
#  {'order_id': '73',
#   'quantity': '2',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Diet Coke]',
#   'item_price': '$2.18 '},
#  {'order_id': '74',
#   'quantity': '1',
#   'item_name': 'Carnitas Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Pinto Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.48 '},
#  {'order_id': '74',
#   'quantity': '1',
#   'item_name': 'Veggie Bowl',
#   'choice_description': '[[Fresh Tomato Salsa (Mild), Roasted Chili Corn Salsa (Medium)], [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '74',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo-Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '75',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '75',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '75',
#   'quantity': '1',
#   'item_name': 'Barbacoa Crispy Tacos',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole]]',
#   'item_price': '$11.75 '},
#  {'order_id': '75',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Cheese, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '76',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[[Tomatillo-Red Chili Salsa (Hot), Fresh Tomato Salsa (Mild)], [Rice, Black Beans, Cheese, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '76',
#   'quantity': '2',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Diet Dr. Pepper]',
#   'item_price': '$2.18 '},
#  {'order_id': '77',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '77',
#   'quantity': '1',
#   'item_name': 'Nantucket Nectar',
#   'choice_description': '[Apple]',
#   'item_price': '$3.39 '},
#  {'order_id': '78',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Green Chili Salsa (Medium), Lettuce]',
#   'item_price': '$8.49 '},
#  {'order_id': '78',
#   'quantity': '1',
#   'item_name': 'Steak Soft Tacos',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), Lettuce]',
#   'item_price': '$8.99 '},
#  {'order_id': '79',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$10.98 '},
#  {'order_id': '80',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Fresh Tomato Salsa (Mild), [Rice, Black Beans, Sour Cream, Guacamole]]',
#   'item_price': '$11.48 '},
#  {'order_id': '81',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Green Chili Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream]]',
#   'item_price': '$8.49 '},
#  {'order_id': '81',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Coca Cola]',
#   'item_price': '$1.09 '},
#  {'order_id': '81',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Dr. Pepper]',
#   'item_price': '$1.09 '},
#  {'order_id': '82',
#   'quantity': '1',
#   'item_name': 'Barbacoa Soft Tacos',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Pinto Beans, Cheese, Sour Cream]]',
#   'item_price': '$9.25 '},
#  {'order_id': '82',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '82',
#   'quantity': '1',
#   'item_name': 'Chips and Fresh Tomato Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.95 '},
#  {'order_id': '83',
#   'quantity': '1',
#   'item_name': 'Steak Soft Tacos',
#   'choice_description': '[Fresh Tomato Salsa, [Cheese, Sour Cream]]',
#   'item_price': '$9.25 '},
#  {'order_id': '83',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '83',
#   'quantity': '1',
#   'item_name': 'Veggie Salad Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '84',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Fresh Tomato Salsa (Mild), [Rice, Fajita Veggies, Guacamole, Lettuce]]',
#   'item_price': '$11.48 '},
#  {'order_id': '84',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '84',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Rice, Cheese, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '85',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Fajita Veggies, Cheese, Lettuce, Sour Cream, Rice]]',
#   'item_price': '$8.99 '},
#  {'order_id': '85',
#   'quantity': '1',
#   'item_name': 'Chips and Roasted Chili-Corn Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '86',
#   'quantity': '1',
#   'item_name': 'Veggie Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '86',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '86',
#   'quantity': '1',
#   'item_name': 'Chips and Fresh Tomato Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.95 '},
#  {'order_id': '87',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Coca Cola]',
#   'item_price': '$1.09 '},
#  {'order_id': '87',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Rice, Black Beans, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '88',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Rice, Cheese, Sour Cream]]',
#   'item_price': '$8.49 '},
#  {'order_id': '88',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo-Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '89',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Fajita Veggies, Guacamole, Lettuce]]',
#   'item_price': '$10.98 '},
#  {'order_id': '89',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Diet Coke]',
#   'item_price': '$1.09 '},
#  {'order_id': '89',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$3.99 '},
#  {'order_id': '90',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '90',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Rice, Pinto Beans, Sour Cream, Cheese, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '91',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '91',
#   'quantity': '1',
#   'item_name': 'Nantucket Nectar',
#   'choice_description': '[Peach Orange]',
#   'item_price': '$3.39 '},
#  {'order_id': '92',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Cheese, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '92',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '92',
#   'quantity': '1',
#   'item_name': 'Chips',
#   'choice_description': 'NULL',
#   'item_price': '$2.15 '},
#  {'order_id': '93',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '93',
#   'quantity': '1',
#   'item_name': 'Veggie Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '93',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '93',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '94',
#   'quantity': '2',
#   'item_name': 'Chicken Salad Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole]]',
#   'item_price': '$22.50 '},
#  {'order_id': '95',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '95',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '96',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '96',
#   'quantity': '2',
#   'item_name': 'Chicken Crispy Tacos',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$17.50 '},
#  {'order_id': '96',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '97',
#   'quantity': '1',
#   'item_name': 'Barbacoa Bowl',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese]]',
#   'item_price': '$9.25 '},
#  {'order_id': '97',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '97',
#   'quantity': '1',
#   'item_name': 'Chips',
#   'choice_description': 'NULL',
#   'item_price': '$2.15 '},
#  {'order_id': '98',
#   'quantity': '1',
#   'item_name': 'Barbacoa Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Cheese, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '98',
#   'quantity': '2',
#   'item_name': 'Chips',
#   'choice_description': 'NULL',
#   'item_price': '$4.30 '},
#  {'order_id': '98',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Rice, Pinto Beans, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '99',
#   'quantity': '1',
#   'item_name': 'Veggie Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Black Beans, Cheese, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '99',
#   'quantity': '1',
#   'item_name': 'Chips',
#   'choice_description': 'NULL',
#   'item_price': '$2.15 '},
#  {'order_id': '100',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Rice, Black Beans, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '100',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Mountain Dew]',
#   'item_price': '$1.09 '},
#  {'order_id': '101',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo-Green Chili Salsa (Medium), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '101',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$3.99 '},
#  {'order_id': '102',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '102',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.95 '},
#  {'order_id': '102',
#   'quantity': '1',
#   'item_name': 'Chips and Roasted Chili Corn Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.95 '},
#  {'order_id': '103',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '103',
#   'quantity': '2',
#   'item_name': 'Chips and Tomatillo Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$5.90 '},
#  {'order_id': '103',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese]]',
#   'item_price': '$9.25 '},
#  {'order_id': '103',
#   'quantity': '1',
#   'item_name': 'Carnitas Soft Tacos',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Fajita Vegetables, Pinto Beans, Cheese]]',
#   'item_price': '$9.25 '},
#  {'order_id': '103',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '104',
#   'quantity': '1',
#   'item_name': 'Carnitas Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Pinto Beans, Sour Cream, Cheese]]',
#   'item_price': '$9.25 '},
#  {'order_id': '104',
#   'quantity': '1',
#   'item_name': 'Chips and Fresh Tomato Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.95 '},
#  {'order_id': '105',
#   'quantity': '2',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$17.50 '},
#  {'order_id': '106',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Pinto Beans, Cheese, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '106',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream]]',
#   'item_price': '$9.25 '},
#  {'order_id': '107',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$10.98 '},
#  {'order_id': '108',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '108',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Mountain Dew]',
#   'item_price': '$1.09 '},
#  {'order_id': '108',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Dr. Pepper]',
#   'item_price': '$1.09 '},
#  {'order_id': '108',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Mountain Dew]',
#   'item_price': '$1.09 '},
#  {'order_id': '108',
#   'quantity': '1',
#   'item_name': 'Barbacoa Burrito',
#   'choice_description': '[[Tomatillo-Red Chili Salsa (Hot), Fresh Tomato Salsa (Mild), Tomatillo-Green Chili Salsa (Medium)], [Rice, Pinto Beans, Cheese]]',
#   'item_price': '$8.99 '},
#  {'order_id': '109',
#   'quantity': '1',
#   'item_name': 'Chicken Salad',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$10.98 '},
#  {'order_id': '109',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Diet Dr. Pepper]',
#   'item_price': '$1.09 '},
#  {'order_id': '110',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Cheese, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '110',
#   'quantity': '1',
#   'item_name': 'Veggie Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Pinto Beans, Cheese, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '110',
#   'quantity': '1',
#   'item_name': 'Barbacoa Bowl',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Cheese, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '110',
#   'quantity': '1',
#   'item_name': 'Barbacoa Crispy Tacos',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Cheese, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '111',
#   'quantity': '1',
#   'item_name': 'Chicken Salad Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '111',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]',
#   'item_price': '$8.75 '},
#  {'order_id': '112',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Pinto Beans, Rice, Fajita Veggies, Cheese, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '112',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Pinto Beans, Rice, Fajita Veggies, Cheese, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '113',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Rice, Black Beans, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '113',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Mountain Dew]',
#   'item_price': '$1.09 '},
#  {'order_id': '114',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '114',
#   'quantity': '1',
#   'item_name': 'Canned Soft Drink',
#   'choice_description': '[Coke]',
#   'item_price': '$1.25 '},
#  {'order_id': '115',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
# ...
#  {'order_id': '377',
#   'quantity': '2',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Black Beans, Rice, Cheese]]',
#   'item_price': '$17.98 '},
#  {'order_id': '377',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Black Beans, Rice, Cheese]]',
#   'item_price': '$8.99 '},
#  {'order_id': '378',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Fresh Tomato Salsa (Mild), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '378',
#   'quantity': '1',
#   'item_name': 'Side of Chips',
#   'choice_description': 'NULL',
#   'item_price': '$1.69 '},
#  {'order_id': '379',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '379',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '379',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.95 '},
#  {'order_id': '379',
#   'quantity': '3',
#   'item_name': 'Canned Soft Drink',
#   'choice_description': '[Lemonade]',
#   'item_price': '$3.75 '},
#  {'order_id': '379',
#   'quantity': '1',
#   'item_name': 'Steak Crispy Tacos',
#   'choice_description': '[Roasted Chili Corn Salsa, [Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '380',
#   'quantity': '1',
#   'item_name': 'Barbacoa Bowl',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   'item_price': '$11.75 '},
#  {'order_id': '380',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '380',
#   'quantity': '1',
#   'item_name': 'Chips',
#   'choice_description': 'NULL',
#   'item_price': '$2.15 '},
#  {'order_id': '380',
#   'quantity': '1',
#   'item_name': 'Bottled Water',
#   'choice_description': 'NULL',
#   'item_price': '$1.50 '},
#  {'order_id': '381',
#   'quantity': '1',
#   'item_name': 'Chicken Soft Tacos',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), Cheese]',
#   'item_price': '$8.49 '},
#  {'order_id': '381',
#   'quantity': '1',
#   'item_name': 'Chicken Soft Tacos',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), Cheese]',
#   'item_price': '$8.49 '},
#  {'order_id': '381',
#   'quantity': '1',
#   'item_name': 'Nantucket Nectar',
#   'choice_description': '[Pomegranate Cherry]',
#   'item_price': '$3.39 '},
#  {'order_id': '382',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[Fresh Tomato (Mild), [Lettuce, Black Beans, Rice, Cheese]]',
#   'item_price': '$8.69 '},
#  {'order_id': '382',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$3.89 '},
#  {'order_id': '383',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '383',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '384',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '384',
#   'quantity': '1',
#   'item_name': 'Veggie Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '384',
#   'quantity': '1',
#   'item_name': 'Chips',
#   'choice_description': 'NULL',
#   'item_price': '$2.15 '},
#  {'order_id': '384',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '385',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '385',
#   'quantity': '1',
#   'item_name': 'Side of Chips',
#   'choice_description': 'NULL',
#   'item_price': '$1.69 '},
#  {'order_id': '386',
#   'quantity': '1',
#   'item_name': 'Veggie Bowl',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Pinto Beans, Black Beans, Rice, Fajita Veggies, Cheese]]',
#   'item_price': '$8.49 '},
#  {'order_id': '386',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '387',
#   'quantity': '1',
#   'item_name': 'Canned Soft Drink',
#   'choice_description': '[Lemonade]',
#   'item_price': '$1.25 '},
#  {'order_id': '387',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Fajita Vegetables, Sour Cream, Cheese, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '387',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Fajita Vegetables, Cheese, Lettuce, Guacamole]]',
#   'item_price': '$11.75 '},
#  {'order_id': '387',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Fajita Vegetables, Sour Cream, Lettuce, Guacamole]]',
#   'item_price': '$11.75 '},
#  {'order_id': '388',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Pinto Beans, Rice, Cheese, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '388',
#   'quantity': '1',
#   'item_name': 'Bottled Water',
#   'choice_description': 'NULL',
#   'item_price': '$1.09 '},
#  {'order_id': '389',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '389',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$4.45 '},
#  {'order_id': '389',
#   'quantity': '1',
#   'item_name': 'Chicken Crispy Tacos',
#   'choice_description': '[Fresh Tomato Salsa, Lettuce]',
#   'item_price': '$8.75 '},
#  {'order_id': '389',
#   'quantity': '1',
#   'item_name': 'Chips and Fresh Tomato Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.95 '},
#  {'order_id': '389',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]',
#   'item_price': '$8.75 '},
#  {'order_id': '389',
#   'quantity': '1',
#   'item_name': 'Chips',
#   'choice_description': 'NULL',
#   'item_price': '$2.15 '},
#  {'order_id': '390',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$3.99 '},
#  {'order_id': '390',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.49 '},
#  {'order_id': '391',
#   'quantity': '1',
#   'item_name': 'Steak Bowl',
#   'choice_description': '[[Fresh Tomato Salsa (Mild), Roasted Chili Corn Salsa (Medium)], [Pinto Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '391',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$3.99 '},
#  {'order_id': '392',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese]]',
#   'item_price': '$8.49 '},
#  {'order_id': '392',
#   'quantity': '1',
#   'item_name': 'Side of Chips',
#   'choice_description': 'NULL',
#   'item_price': '$1.69 '},
#  {'order_id': '392',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Coca Cola]',
#   'item_price': '$1.09 '},
#  {'order_id': '393',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '393',
#   'quantity': '1',
#   'item_name': 'Canned Soda',
#   'choice_description': '[Sprite]',
#   'item_price': '$1.09 '},
#  {'order_id': '394',
#   'quantity': '1',
#   'item_name': 'Carnitas Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Pinto Beans, Cheese]]',
#   'item_price': '$9.25 '},
#  {'order_id': '394',
#   'quantity': '1',
#   'item_name': 'Veggie Salad Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '395',
#   'quantity': '1',
#   'item_name': 'Steak Soft Tacos',
#   'choice_description': '[Tomatillo-Red Chili Salsa (Hot), [Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.99 '},
#  {'order_id': '395',
#   'quantity': '1',
#   'item_name': 'Chips and Fresh Tomato Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '396',
#   'quantity': '1',
#   'item_name': 'Canned Soft Drink',
#   'choice_description': '[Diet Coke]',
#   'item_price': '$1.25 '},
#  {'order_id': '396',
#   'quantity': '1',
#   'item_name': 'Canned Soft Drink',
#   'choice_description': '[Coke]',
#   'item_price': '$1.25 '},
#  {'order_id': '396',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Sour Cream, Cheese, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '396',
#   'quantity': '1',
#   'item_name': 'Chicken Soft Tacos',
#   'choice_description': '[Fresh Tomato Salsa, [Sour Cream, Cheese, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '397',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream]]',
#   'item_price': '$9.25 '},
#  {'order_id': '397',
#   'quantity': '1',
#   'item_name': 'Steak Soft Tacos',
#   'choice_description': '[Fresh Tomato Salsa, [Cheese, Sour Cream]]',
#   'item_price': '$9.25 '},
#  {'order_id': '398',
#   'quantity': '1',
#   'item_name': 'Chicken Soft Tacos',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Lettuce, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '398',
#   'quantity': '1',
#   'item_name': 'Bottled Water',
#   'choice_description': 'NULL',
#   'item_price': '$1.50 '},
#  {'order_id': '399',
#   'quantity': '1',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$3.99 '},
#  {'order_id': '399',
#   'quantity': '1',
#   'item_name': 'Veggie Burrito',
#   'choice_description': '[Fresh Tomato Salsa (Mild), [Rice, Pinto Beans, Cheese, Sour Cream]]',
#   'item_price': '$8.49 '},
#  {'order_id': '400',
#   'quantity': '1',
#   'item_name': 'Veggie Burrito',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Rice, Fajita Vegetables, Pinto Beans, Sour Cream, Cheese, Lettuce, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '400',
#   'quantity': '1',
#   'item_name': 'Carnitas Burrito',
#   'choice_description': '[Tomatillo Red Chili Salsa]',
#   'item_price': '$9.25 '},
#  {'order_id': '400',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Lettuce, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '401',
#   'quantity': '2',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Lettuce]]',
#   'item_price': '$17.50 '},
#  {'order_id': '402',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '402',
#   'quantity': '2',
#   'item_name': 'Chips and Guacamole',
#   'choice_description': 'NULL',
#   'item_price': '$8.90 '},
#  {'order_id': '402',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '402',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$8.75 '},
#  {'order_id': '403',
#   'quantity': '1',
#   'item_name': 'Barbacoa Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Black Beans, Rice, Cheese, Sour Cream]]',
#   'item_price': '$8.99 '},
#  {'order_id': '403',
#   'quantity': '1',
#   'item_name': 'Chips and Tomatillo-Green Chili Salsa',
#   'choice_description': 'NULL',
#   'item_price': '$2.39 '},
#  {'order_id': '404',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Pinto Beans, Cheese, Guacamole, Lettuce]]',
#   'item_price': '$11.25 '},
#  {'order_id': '404',
#   'quantity': '1',
#   'item_name': 'Carnitas Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Pinto Beans, Cheese, Sour Cream, Lettuce]]',
#   'item_price': '$9.25 '},
#  {'order_id': '404',
#   'quantity': '1',
#   'item_name': 'Chips',
#   'choice_description': 'NULL',
#   'item_price': '$2.15 '},
#  {'order_id': '405',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Cheese, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '405',
#   'quantity': '1',
#   'item_name': 'Canned Soft Drink',
#   'choice_description': '[Diet Coke]',
#   'item_price': '$1.25 '},
#  {'order_id': '406',
#   'quantity': '1',
#   'item_name': 'Barbacoa Soft Tacos',
#   'choice_description': '[Tomatillo Red Chili Salsa, [Black Beans, Cheese, Sour Cream, Guacamole]]',
#   'item_price': '$11.75 '},
#  {'order_id': '406',
#   'quantity': '1',
#   'item_name': 'Canned Soft Drink',
#   'choice_description': '[Diet Coke]',
#   'item_price': '$1.25 '},
#  {'order_id': '407',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Sour Cream, Cheese, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '407',
#   'quantity': '1',
#   'item_name': 'Steak Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Sour Cream, Cheese, Guacamole]]',
#   'item_price': '$11.75 '},
#  {'order_id': '408',
#   'quantity': '1',
#   'item_name': 'Canned Soft Drink',
#   'choice_description': '[Coke]',
#   'item_price': '$1.25 '},
#  {'order_id': '408',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Tomatillo Green Chili Salsa, [Rice, Sour Cream, Cheese, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '408',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Fresh Tomato Salsa, [Rice, Fajita Vegetables, Pinto Beans, Sour Cream, Cheese, Lettuce, Guacamole]]',
#   'item_price': '$11.25 '},
#  {'order_id': '409',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[[Fresh Tomato Salsa (Mild), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream]]',
#   'item_price': '$8.49 '},
#  {'order_id': '409',
#   'quantity': '1',
#   'item_name': 'Chicken Bowl',
#   'choice_description': '[Roasted Chili Corn Salsa (Medium), [Black Beans, Rice, Sour Cream, Guacamole]]',
#   'item_price': '$10.98 '},
#  {'order_id': '410',
#   'quantity': '1',
#   'item_name': 'Chicken Burrito',
#   'choice_description': '[Roasted Chili Corn Salsa, [Rice, Black Beans]]',
#   'item_price': '$8.75 '},
#  {'order_id': '410',
#   'quantity': '1',
#   'item_name': 'Canned Soft Drink',
#   'choice_description': '[Diet Coke]',
#   'item_price': '$1.25 '},
#  {'order_id': '410',
#   'quantity': '1',
#   'item_name': 'Chicken Soft Tacos',
#   'choice_description': '[Roasted Chili Corn Salsa, [Black Beans, Lettuce]]',
#   'item_price': '$8.75 '},
#  ...]

# %% [markdown]
# ### Part 2: Separate `file_nested_list` into the `header` and the `data`.

# %%
#the first index is the header 
header = file_nested_list[0]
#the rest is stored in data
data = file_nested_list[1:]


#print(header)
#print(data)

# %% [markdown]
# ---
#
# ## Intermediate Level

# %% [markdown]
# ### Part 3: Calculate the average price of an order.
#
# Hint: Examine the data to see if the `quantity` column is relevant to this calculation.
#
# Hint: Think carefully about the simplest way to do this!

# %%
total_order_list = {}
for row in data:
    if not row[0] in total_order_list:
        total_order_list[row[0]] = []
#above code initialises a dictionary with empty lits        
#print(total_order_list)
        
for row in data:
    #print(row[0], row[4])
    total_order_list[row[0]].append(float(row[4][1:]))

#print(total_order_list)


order_avg_cost = []
#print(list(total_order_list.values()))

for i in list(total_order_list.values()):
    #print(i, sum(i)/len(i))
    order_avg_cost.append(sum(i)/len(i))
    
total_avg = sum(order_avg_cost)/len(order_avg_cost)

print(total_avg)
# Out:
# 7.841910975496643

# %% [markdown]
# ### Part 4: Create a list (or set) named `unique_sodas` containing all of unique sodas and soft drinks that Chipotle sells.
#
# Note: Just look for `'Canned Soda'` and `'Canned Soft Drink'`, and ignore other drinks like `'Izze'`.

# %%
#initilise the list
unique_sodas = []
Soda = ['Canned Soda' , 'Canned Soft Drink']

for row in data:
    #print(row[2])
    if row[2] in Soda:
        #print(row[3][1:len(row[3])-1])
        if not row[3][1:len(row[3])-1] in unique_sodas:
            
            unique_sodas.append(row[3][1:len(row[3])-1])

print(unique_sodas)
# Out:
# ['Sprite', 'Dr. Pepper', 'Mountain Dew', 'Diet Dr. Pepper', 'Coca Cola', 'Diet Coke', 'Coke', 'Lemonade', 'Nestea']

# %% [markdown]
# ---
#
# ## Advanced Level

# %% [markdown]
# ### Part 5: Calculate the average number of toppings per burrito.
#
# Note: Let's ignore the `quantity` column to simplify this task.
#
# Hint: Think carefully about the easiest way to count the number of toppings!

# %% [markdown]
# ### Part 6: Create a dictionary. Let the keys represent chip orders and the values represent the total number of orders.
#
# Expected output: `{'Chips and Roasted Chili-Corn Salsa': 18, ... }`
#
# Note: Please take the `quantity` column into account!
#
# Optional: Learn how to use `.defaultdict()` to simplify your code.

# %% [markdown]
# ---
#
# ## Bonus: Craft a problem statement about this data that interests you, and then answer it!
