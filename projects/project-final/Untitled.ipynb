# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display plots in-notebook
# %matplotlib inline

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

loc = './impaired-driving-death-rate-by-age-and-gender-2012-2014-all-states.csv'
data = pd.read_csv(loc)

# %%
data
# Out:
#                   State                                            Location  \
# 0          United States  {'human_address': '{"address":"United States",...
# 1                Alabama  {'human_address': '{"address":"Alabama","city"...
# 2                 Alaska  {'human_address': '{"address":"Alaska","city":...
# 3                Arizona  {'human_address': '{"address":"Arizona","city"...
# 4               Arkansas  {'human_address': '{"address":"Arkansas","city...
# 5             California  {'human_address': '{"address":"California","ci...
# 6               Colorado  {'human_address': '{"address":"Colorado","city...
# 7            Connecticut  {'human_address': '{"address":"Connecticut","c...
# 8               Delaware  {'human_address': '{"address":"Delaware","city...
# 9   District of Columbia  {'human_address': '{"address":"District of Col...
# 10               Florida  {'human_address': '{"address":"Florida","city"...
# 11               Georgia  {'human_address': '{"address":"Georgia","city"...
# 12                Hawaii  {'human_address': '{"address":"Hawaii","city":...
# 13                 Idaho  {'human_address': '{"address":"Idaho","city":"...
# 14              Illinois  {'human_address': '{"address":"Illinois","city...
# 15               Indiana  {'human_address': '{"address":"Indiana","city"...
# 16                  Iowa  {'human_address': '{"address":"Iowa","city":""...
# 17                Kansas  {'human_address': '{"address":"Kansas","city":...
# 18              Kentucky  {'human_address': '{"address":"Kentucky","city...
# 19             Louisiana  {'human_address': '{"address":"Louisiana","cit...
# 20                 Maine  {'human_address': '{"address":"Maine","city":"...
# 21              Maryland  {'human_address': '{"address":"Maryland","city...
# 22         Massachusetts  {'human_address': '{"address":"Massachusetts",...
# 23              Michigan  {'human_address': '{"address":"Michigan","city...
# 24             Minnesota  {'human_address': '{"address":"Minnesota","cit...
# 25           Mississippi  {'human_address': '{"address":"Mississippi","c...
# 26              Missouri  {'human_address': '{"address":"Missouri","city...
# 27               Montana  {'human_address': '{"address":"Montana","city"...
# 28              Nebraska  {'human_address': '{"address":"Nebraska","city...
# 29                Nevada  {'human_address': '{"address":"Nevada","city":...
# 30         New Hampshire  {'human_address': '{"address":"New Hampshire",...
# 31            New Jersey  {'human_address': '{"address":"New Jersey","ci...
# 32            New Mexico  {'human_address': '{"address":"New Mexico","ci...
# 33              New York  {'human_address': '{"address":"New York","city...
# 34        North Carolina  {'human_address': '{"address":"North Carolina"...
# 35          North Dakota  {'human_address': '{"address":"North Dakota","...
# 36                  Ohio  {'human_address': '{"address":"Ohio","city":""...
# 37              Oklahoma  {'human_address': '{"address":"Oklahoma","city...
# 38                Oregon  {'human_address': '{"address":"Oregon","city":...
# 39          Pennsylvania  {'human_address': '{"address":"Pennsylvania","...
# 40          Rhode Island  {'human_address': '{"address":"Rhode Island","...
# 41        South Carolina  {'human_address': '{"address":"South Carolina"...
# 42          South Dakota  {'human_address': '{"address":"South Dakota","...
# 43             Tennessee  {'human_address': '{"address":"Tennessee","cit...
# 44                 Texas  {'human_address': '{"address":"Texas","city":"...
# 45                  Utah  {'human_address': '{"address":"Utah","city":""...
# 46               Vermont  {'human_address': '{"address":"Vermont","city"...
# 47              Virginia  {'human_address': '{"address":"Virginia","city...
# 48            Washington  {'human_address': '{"address":"Washington","ci...
# 49         West Virginia  {'human_address': '{"address":"","city":"West"...
# 50             Wisconsin  {'human_address': '{"address":"Wisconsin","cit...
# 51               Wyoming  {'human_address': '{"address":"Wyoming","city"...
#
#     All Ages, 2012  All Ages, 2014  Ages 0-20, 2012  Ages 0-20, 2014  \
# 0              3.3             3.1              1.3              1.2
# 1              5.5             5.5              2.7              2.1
# 2              NaN             2.8              NaN              NaN
# 3              3.6             3.0              1.6              NaN
# 4              5.1             4.6              NaN              NaN
# 5              2.0             2.2              0.9              1.0
# 6              2.5             3.0              NaN              1.7
# 7              2.4             2.7              NaN              NaN
# 8              3.8             5.2              NaN              NaN
# 9              NaN             NaN              NaN              NaN
# 10             3.7             3.5              1.2              1.2
# 11             3.0             2.7              1.0              0.8
# 12             3.8             2.2              NaN              NaN
# 13             3.6             3.3              NaN              NaN
# 14             2.5             2.4              0.7              0.7
# 15             3.6             3.2              1.2              NaN
# 16             3.2             3.0              NaN              NaN
# 17             3.4             3.6              2.3              NaN
# 18             4.0             3.9              1.8              2.0
# 19             5.2             5.4              2.8              1.8
# 20             3.8             3.3              NaN              NaN
# 21             2.7             2.2              1.6              NaN
# 22             1.8             1.9              NaN              NaN
# 23             2.7             2.2              1.1              1.0
# 24             2.1             1.9              NaN              NaN
# 25             6.1             6.0              2.6              2.8
# 26             4.8             3.4              1.9              NaN
# 27             9.4             7.3              NaN              NaN
# 28             4.0             3.3              NaN              NaN
# 29             2.8             3.3              NaN              NaN
# 30             2.4             2.4              NaN              NaN
# 31             1.8             1.8              NaN              NaN
# 32             4.8             5.7              NaN              NaN
# 33             1.7             1.6              0.6              0.7
# 34             4.2             3.8              1.7              1.4
# 35            11.3             7.2              NaN              NaN
# 36             3.5             2.7              1.2              0.8
# 37             5.6             4.0              NaN              NaN
# 38             2.2             2.5              NaN              NaN
# 39             3.3             2.7              1.4              0.7
# 40             2.3             NaN              NaN              NaN
# 41             7.6             5.8              2.8              2.0
# 42             5.7             5.6              NaN              NaN
# 43             4.6             4.1              1.6              NaN
# 44             4.9             5.4              2.1              2.3
# 45             1.2             2.0              NaN              NaN
# 46             3.4             NaN              NaN              NaN
# 47             2.5             2.5              1.2              1.2
# 48             2.1             1.9              NaN              NaN
# 49             5.6             4.7              NaN              NaN
# 50             3.6             2.9              1.6              NaN
# 51             7.1             8.2              NaN              NaN
#
#     Ages 21-34, 2012  Ages 21-34, 2014  Ages 35+, 2012  Ages 35+, 2014  \
# 0                6.7               6.2             3.1             3.0
# 1               10.3              10.0             5.0             5.5
# 2                NaN               NaN             NaN             NaN
# 3                6.9               5.5             3.3             3.1
# 4               10.5               6.3             4.3             5.4
# 5                4.5               4.6             1.8             2.0
# 6                5.6               5.6             2.0             2.6
# 7                5.9               6.1             2.1             2.5
# 8                NaN              11.7             4.0             4.6
# 9                NaN               NaN             NaN             NaN
# 10               8.0               7.4             3.3             3.1
# 11               5.8               5.2             3.1             2.9
# 12               NaN               NaN             3.2             NaN
# 13               8.7               NaN             2.7             3.0
# 14               6.0               5.5             2.1             2.2
# 15               7.2               6.3             3.5             3.2
# 16               5.9               4.6             2.9             3.4
# 17               6.0               7.4             3.0             3.3
# 18               7.2               7.8             3.7             3.4
# 19               8.6               9.4             5.1             5.7
# 20               NaN               NaN             2.8             3.1
# 21               5.8               5.4             2.2             1.8
# 22               3.3               4.0             1.7             1.8
# 23               6.8               5.1             2.0             1.8
# 24               3.7               3.5             2.2             2.1
# 25              12.0              10.8             5.7             5.8
# 26               9.5               6.9             4.4             3.2
# 27              21.4              15.4             7.2             6.9
# 28               6.5               7.0             3.5             3.0
# 29               4.6               6.4             3.2             2.7
# 30               NaN               NaN             2.9             NaN
# 31               4.6               3.6             1.4             1.7
# 32               9.1              11.2             4.5             5.1
# 33               3.3               3.0             1.7             1.5
# 34               8.0               7.7             4.0             3.6
# 35              15.3              15.2            12.0             6.1
# 36               6.8               5.6             3.3             2.6
# 37              10.5               7.4             5.8             3.9
# 38               5.2               4.2             1.8             2.6
# 39               7.2               5.5             2.8             2.7
# 40               NaN               NaN             NaN             NaN
# 41              14.2              12.4             7.6             5.3
# 42               NaN               NaN             NaN             6.2
# 43               8.0               8.2             4.9             4.1
# 44              10.0              10.0             4.7             5.3
# 45               NaN               NaN             1.9             2.3
# 46               NaN               NaN             NaN             NaN
# 47               4.5               5.1             2.6             2.3
# 48               4.0               3.4             2.0             1.9
# 49              12.9              10.0             4.4             4.0
# 50               6.5               7.5             3.5             2.3
# 51              17.3               NaN             NaN             8.1
#
#     Male, 2012  Male, 2014  Female, 2012  Female, 2014
# 0          5.2         4.9           1.5           1.4
# 1          8.4         8.6           2.9           2.6
# 2          NaN         NaN           NaN           NaN
# 3          5.4         4.5           1.7           1.5
# 4          8.1         7.2           2.2           2.2
# 5          3.2         3.4           1.0           1.1
# 6          3.9         4.6           1.1           1.3
# 7          3.7         4.6           1.1           NaN
# 8          6.6         7.4           NaN           NaN
# 9          NaN         NaN           NaN           NaN
# 10         5.7         5.4           1.7           1.7
# 11         4.9         4.7           1.2           0.9
# 12         5.7         3.6           NaN           NaN
# 13         5.8         4.8           NaN           NaN
# 14         4.0         3.7           1.0           1.3
# 15         6.0         5.1           1.3           1.3
# 16         5.1         4.8           NaN           NaN
# 17         6.0         5.8           NaN           1.4
# 18         6.5         6.5           1.5           1.3
# 19         8.3         9.1           2.4           1.9
# 20         6.6         5.1           NaN           NaN
# 21         4.1         3.5           1.4           0.9
# 22         2.7         3.1           0.9           0.9
# 23         4.3         3.3           1.2           1.1
# 24         3.2         3.0           1.2           0.9
# 25         9.8         9.4           2.7           2.8
# 26         7.8         5.6           1.8           1.3
# 27        14.9        10.2           4.0           4.3
# 28         6.4         5.0           NaN           NaN
# 29         4.2         4.9           1.4           1.7
# 30         4.1         3.2           NaN           NaN
# 31         2.9         2.9           0.9           0.8
# 32         6.9         8.6           2.9           2.8
# 33         2.7         2.4           0.8           0.8
# 34         6.8         6.3           1.7           1.5
# 35        17.4        10.7           NaN           NaN
# 36         5.5         4.2           1.6           1.3
# 37         9.3         6.0           1.9           2.1
# 38         3.1         3.7           1.3           1.4
# 39         5.4         4.4           1.3           1.1
# 40         NaN         NaN           NaN           NaN
# 41        12.3         9.0           3.2           2.9
# 42         7.4         8.7           NaN           NaN
# 43         7.5         6.8           1.8           1.5
# 44         7.6         8.1           2.4           2.7
# 45         1.7         3.0           NaN           NaN
# 46         NaN         NaN           NaN           NaN
# 47         4.1         3.9           0.9           1.2
# 48         3.6         2.9           0.7           0.9
# 49         9.3         7.1           NaN           NaN
# 50         5.6         4.8           1.6           1.2
# 51        11.3        13.1           NaN           NaN

# %%
data.describe()
# Out:
#        All Ages, 2012  All Ages, 2014  Ages 0-20, 2012  Ages 0-20, 2014  \
# count       50.000000       49.000000        24.000000        18.000000
# mean         3.916000        3.624490         1.620833         1.411111
# std          1.947092        1.581604         0.647389         0.635137
# min          1.200000        1.600000         0.600000         0.700000
# 25%          2.500000        2.500000         1.200000         0.850000
# 50%          3.600000        3.200000         1.600000         1.200000
# 75%          4.800000        4.600000         1.950000         1.950000
# max         11.300000        8.200000         2.800000         2.800000
#
#        Ages 21-34, 2012  Ages 21-34, 2014  Ages 35+, 2012  Ages 35+, 2014  \
# count         42.000000         41.000000       46.000000       46.000000
# mean           7.971429          7.173171        3.584783        3.536957
# std            3.833249          3.014882        1.896543        1.568490
# min            3.300000          3.000000        1.400000        1.500000
# 25%            5.800000          5.200000        2.200000        2.350000
# 50%            6.850000          6.300000        3.200000        3.100000
# 75%            9.400000          8.200000        4.375000        4.475000
# max           21.400000         15.400000       12.000000        8.100000
#
#        Male, 2012  Male, 2014  Female, 2012  Female, 2014
# count   48.000000   48.000000     35.000000     35.000000
# mean     6.270833    5.658333      1.662857      1.600000
# std      3.101472    2.425821      0.759290      0.772315
# min      1.700000    2.400000      0.700000      0.800000
# 25%      4.100000    3.700000      1.150000      1.100000
# 50%      5.700000    4.900000      1.500000      1.300000
# 75%      7.525000    7.125000      1.850000      1.800000
# max     17.400000   13.100000      4.000000      4.300000

# %%
data.isnull().sum()
# Out:
# State                0
# Location             0
# All Ages, 2012       2
# All Ages, 2014       3
# Ages 0-20, 2012     28
# Ages 0-20, 2014     34
# Ages 21-34, 2012    10
# Ages 21-34, 2014    11
# Ages 35+, 2012       6
# Ages 35+, 2014       6
# Male, 2012           4
# Male, 2014           4
# Female, 2012        17
# Female, 2014        17
# dtype: int64

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-3d8483998d6f> in <module>
# ----> 1 data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
sns.pairplot(data, x_vars=feature_cols, y_vars='total_rentals');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-14cee7d15c3b> in <module>
# ----> 1 sns.pairplot(data, x_vars=feature_cols, y_vars='total_rentals');
#
# NameError: name 'sns' is not defined
